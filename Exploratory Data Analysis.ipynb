# %%
import pandas as pd
import sys
data = pd.read_excel('/Users/ramanlaldomadia/Desktop/Capstone/news_data.xlsx')
data=read_file.drop(columns=['Unnamed: 0'])
print(data.columns)
data.shape
print("----Dataset Information----")
data.info()
print("----Size of Dataset----")
print("An integer takes", sys.getsizeof(data), "bytes")
data.head(3)
# Out:
# Index(['date', 'date/time', 'author', 'title', 'article', 'publication'], dtype='object')
# ----Dataset Information----
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
# date           1000 non-null object
# date/time      1000 non-null object
# author         694 non-null object
# title          1000 non-null object
# article        998 non-null object
# publication    1000 non-null object
# dtypes: object(6)
# memory usage: 47.0+ KB
# ----Size of Dataset----
# An integer takes 7871722 bytes
#         date           date/time       author  \
# 0  12/9/2016  12/9/2016 18:31:00  Lee Drutman
# 1  10/7/2016  10/7/2016 21:26:46  Scott Davis
# 2  1/26/2018  1/26/2018 00:00:00          NaN
#
#                                                title  \
# 0  We should take concerns about the health of li...
# 1  Colts GM Ryan Grigson says Andrew Luck's contr...
# 2       Trump denies report he ordered Mueller fired
#
#                                              article       publication
# 0  This post is part of Polyarchy, an independent...               Vox
# 1   The Indianapolis Colts made Andrew Luck the h...  Business Insider
# 2  DAVOS, Switzerland (Reuters) - U.S. President ...           Reuters

# %%
data.describe()
# Out:
#              date           date/time       author          title  \
# count        1000                1000          694           1000
# unique        638                 835          452            999
# top     6/11/2019  6/11/2019 00:00:00  Kurt Wagner  Art Movements
# freq            8                   8           14              2
#
#                                             article publication
# count                                           998        1000
# unique                                          995           7
# top     Advertise on Hyperallergic with Nectar Ads      Reuters
# freq                                              3         273

# %%
data.value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-ea7f7c3e2bfc> in <module>
# ----> 1 data.value_counts(dropna=False)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
data.apply(pd.Series.value_counts)
# Out:
#                                                     date  date/time  author  \
# \nMeet Dufferin Starship, the Band Who Made an ...   NaN        NaN     NaN
#   Check out more of Paige Mehrer's work on her ...   NaN        NaN     NaN
#   In August 1986, jazz legend Sonny Rollins and...   NaN        NaN     NaN
#   Want the best from VICE News in your inbox? S...   NaN        NaN     NaN
#   Want the best of VICE News in your inbox? Sig...   NaN        NaN     NaN
# ...                                                  ...        ...     ...
# “Elizabeth Warren called me!” is turning into a...   NaN        NaN     NaN
# “He is wired differently to you and me, this ch...   NaN        NaN     NaN
# “In Mexico, Time Is Not Money”: A Residency Pus...   NaN        NaN     NaN
# “Slow,” “steady” and “deliberate” are rarely us...   NaN        NaN     NaN
# “We’re not doing anything with blockchain,” sai...   NaN        NaN     NaN
#
#                                                     title  article  \
# \nMeet Dufferin Starship, the Band Who Made an ...    1.0      NaN
#   Check out more of Paige Mehrer's work on her ...    NaN      1.0
#   In August 1986, jazz legend Sonny Rollins and...    NaN      1.0
#   Want the best from VICE News in your inbox? S...    NaN      1.0
#   Want the best of VICE News in your inbox? Sig...    NaN      1.0
# ...                                                   ...      ...
# “Elizabeth Warren called me!” is turning into a...    1.0      NaN
# “He is wired differently to you and me, this ch...    NaN      1.0
# “In Mexico, Time Is Not Money”: A Residency Pus...    1.0      NaN
# “Slow,” “steady” and “deliberate” are rarely us...    NaN      1.0
# “We’re not doing anything with blockchain,” sai...    NaN      1.0
#
#                                                     publication
# \nMeet Dufferin Starship, the Band Who Made an ...          NaN
#   Check out more of Paige Mehrer's work on her ...          NaN
#   In August 1986, jazz legend Sonny Rollins and...          NaN
#   Want the best from VICE News in your inbox? S...          NaN
#   Want the best of VICE News in your inbox? Sig...          NaN
# ...                                                         ...
# “Elizabeth Warren called me!” is turning into a...          NaN
# “He is wired differently to you and me, this ch...          NaN
# “In Mexico, Time Is Not Money”: A Residency Pus...          NaN
# “Slow,” “steady” and “deliberate” are rarely us...          NaN
# “We’re not doing anything with blockchain,” sai...          NaN
#
# [3925 rows x 6 columns]

# %%
df.corr()
